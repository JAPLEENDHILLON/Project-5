# %%
#Importing investpy library for investing.com
import investpy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Crypto1=input('Enter First Crypto: ')
Crypto2=input('Enter Second Crypto: ')
Crypto3=input('Enter Third Crypto: ')
Crypto4=input('Enter Fourth Crypto: ')
Crypto5=input('Enter Fifth Crypto: ')

def cryptocurrency(crypto):
    crypto_data=investpy.get_crypto_historical_data(crypto=crypto,from_date='25/06/2015',to_date='25/06/2021')
    return(crypto_data)



#Calling the functions on the basis of the inputs
df1=cryptocurrency(Crypto1)
df2=cryptocurrency(Crypto2)
df3=cryptocurrency(Crypto3)
df4=cryptocurrency(Crypto4)
df5=cryptocurrency(Crypto5)
# Out:
# Enter First Crypto:  Bitcoin
# Enter Second Crypto:  Ethereum
# Enter Third Crypto:  Cardano
# Enter Fourth Crypto:  Dogecoin
# Enter Fifth Crypto:  Tether

# %%
#Defining the list and storing dataframes in the list
list_crypto=[df1,df2,df3,df4,df5]
crypto_dataframe=pd.DataFrame()
#Concatnating the dateframe
for i in list_crypto:
    crypto_dataframe=pd.concat([crypto_dataframe,i],axis=1)

#Getting the closing prices
crypto_dataframe=crypto_dataframe['Close']


#Renaming the columns
crypto_dataframe.columns=[Crypto1,Crypto2,Crypto3,Crypto4,Crypto5]

crypto_dataframe.head()
# Out:
#             Bitcoin  Ethereum  Cardano  Dogecoin  Tether
# Date
# 2015-06-25    242.6       NaN      NaN       NaN     NaN
# 2015-06-26    242.9       NaN      NaN       NaN     NaN
# 2015-06-27    250.7       NaN      NaN       NaN     NaN
# 2015-06-28    248.9       NaN      NaN       NaN     NaN
# 2015-06-29    257.0       NaN      NaN       NaN     NaN

# %%
#Checking For Null Values
crypto_dataframe.isnull().sum()
# Out:
# Bitcoin       0
# Ethereum    259
# Cardano     920
# Dogecoin    709
# Tether      660
# dtype: int64

# %%
# Dropping the NA's
crypto_dataframe=crypto_dataframe.dropna()
#Chcecking for NA's again
crypto_dataframe.isnull().sum()
# Out:
# Bitcoin     0
# Ethereum    0
# Cardano     0
# Dogecoin    0
# Tether      0
# dtype: int64

# %%
#Calculating Daily Returns
crypto_daily_returns=crypto_dataframe.pct_change()
#Dropping Null from daily returns
crypto_daily_returns=crypto_daily_returns.dropna()
crypto_daily_returns
# Out:
#              Bitcoin  Ethereum   Cardano  Dogecoin    Tether
# Date
# 2018-01-01 -0.029277  0.021296 -0.010986 -0.027893 -0.009804
# 2018-01-02  0.097375  0.141297  0.085161  0.037105  0.009901
# 2018-01-03  0.027281  0.096917  0.417323  0.022778 -0.009804
# 2018-01-04  0.001550 -0.002134  0.022500  0.044324  0.009901
# 2018-01-05  0.116910  0.024223 -0.099065  0.305524 -0.019608
# ...              ...       ...       ...       ...       ...
# 2021-06-21 -0.109670 -0.157176 -0.175999 -0.357162  0.000699
# 2021-06-22  0.025382 -0.007678 -0.020214  0.061197 -0.000499
# 2021-06-23  0.036247  0.048879  0.085584  0.234234 -0.000699
# 2021-06-24  0.029444  0.010542  0.085134  0.118646 -0.000500
# 2021-06-25 -0.088612 -0.089772 -0.075389 -0.096051 -0.000200
#
# [1271 rows x 5 columns]

# %%
df1.head()
# Out:
#              Open   High    Low  Close  Volume Currency
# Date
# 2015-06-25  240.6  243.6  239.3  242.6   40360      USD
# 2015-06-26  242.6  243.5  240.1  242.9   37618      USD
# 2015-06-27  242.9  251.6  241.8  250.7   54700      USD
# 2015-06-28  250.7  251.6  246.6  248.9   39892      USD
# 2015-06-29  248.9  257.5  248.0  257.0   92643      USD

# %%
#Defining a function for the Fibonacci Retracement
def plot_fib_ret(data,crypto_name):
    max_price = data['Close'].max()
    min_price = data['Close'].min()
    diff = max_price - min_price     
    Level1 = max_price - diff * 0.236   
    Level2 = max_price - diff * 0.382  
    Level3= max_price - diff * 0.5     
    Level4 = max_price - diff * 0.618  

    print("Level------------", "Price")
    print("00.0%\t\t", max_price)
    print("23.6%\t\t", Level1)
    print("38.2%\t\t", Level2)
    print("50.0%\t\t", Level3)
    print("61.8%\t\t", Level4)
    print("100.0%\t\t", min_price)
    

    fibonacci = plt.figure(figsize=(20,5))
    plt.style.use('fivethirtyeight')
    plt.title('Fibonnacci Retracement')
    plt.plot(data.index, data['Close'])
    plt.axhline(max_price, alpha=1, color = 'red')
    plt.axhline(Level1,color = 'orange')
    plt.axhline(Level2,color = 'yellow')
    plt.axhline(Level3,color = 'green')
    plt.axhline(Level4,color = 'blue')
    plt.axhline(min_price,color = 'black')
    plt.xlabel('Date',fontsize=15)
    plt.ylabel(f'Closing Price {crypto_name}',fontsize=15)
    plt.show()

# %%
plot_fib_ret(df1,Crypto1)
plot_fib_ret(df2,Crypto2)
plot_fib_ret(df3,Crypto3)
plot_fib_ret(df4,Crypto4)
plot_fib_ret(df5,Crypto5)
# Out:
# Level------------ Price
# 00.0%		 63540.9
# 23.6%		 48595.138000000006
# 38.2%		 39349.031
# 50.0%		 31876.15
# 61.8%		 24403.269
# 100.0%		 211.4
# Level------------ Price
# 00.0%		 4167.78
# 23.6%		 3185.76512
# 38.2%		 2578.2474399999996
# 50.0%		 2087.24
# 61.8%		 1596.23256
# 100.0%		 6.7
# Level------------ Price
# 00.0%		 2.300278
# 23.6%		 1.762892784
# 38.2%		 1.430442608
# 50.0%		 1.16175
# 61.8%		 0.893057392
# 100.0%		 0.023222
# Level------------ Price
# 00.0%		 0.68688
# 23.6%		 0.5249589840000001
# 38.2%		 0.42478750800000004
# 50.0%		 0.34382700000000005
# 61.8%		 0.26286649200000006
# 100.0%		 0.000774
# Level------------ Price
# 00.0%		 1.06
# 23.6%		 1.023184
# 38.2%		 1.000408
# 50.0%		 0.982
# 61.8%		 0.963592
# 100.0%		 0.904

# %%
#Calculate and plot (ADRIAN)
import investpy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


'''

1)Exponential Moving Average
2)Standard Deviation
3)Variance
4)Covariance
5)Cumulative Returns By assigning weights
6)Correlation
7)Sharp Ratios
8)Rolling Averages'''
# Out:
# '\n\n1)Exponential Moving Average\n2)Standard Deviation\n3)Variance\n4)Covariance\n5)Cumulative Returns By assigning weights\n6)Correlation\n7)Sharp Ratios\n8)Rolling Averages'

# %%
# Exponential 30 Day Moving Average Crypto 1 
Crypto_1_EMA= df1['Close'].ewm(span=30, adjust=False).mean()
Crypto_1_EMA
# Out:
# Date
# 2015-06-25      242.600000
# 2015-06-26      242.619355
# 2015-06-27      243.140687
# 2015-06-28      243.512255
# 2015-06-29      244.382432
#                   ...
# 2021-06-21    38292.640717
# 2021-06-22    37918.689703
# 2021-06-23    37644.858109
# 2021-06-24    37452.660812
# 2021-06-25    37074.682695
# Name: Close, Length: 2193, dtype: float64

# %%
Crypto_1_EMA.plot(figsize=(25,10))

# %%
# Exponential 30 Day Moving Average Crypto 2
Crypto_2_EMA = df2['Close'].ewm(span=30, adjust=False).mean()
Crypto_2_EMA.plot(figsize=(25,10))

# %%
# Exponential 30 Day Moving Average Crypto 3
Crypto_3_EMA = df3['Close'].ewm(span=30, adjust=False).mean()
Crypto_3_EMA
# Out:
# Date
# 2017-12-31    0.710000
# 2018-01-01    0.709497
# 2018-01-02    0.712884
# 2018-01-03    0.736569
# 2018-01-04    0.760294
#                 ...
# 2021-06-21    1.527039
# 2021-06-22    1.502842
# 2021-06-23    1.486566
# 2021-06-24    1.478209
# 2021-06-25    1.463792
# Name: Close, Length: 1273, dtype: float64

# %%
Crypto_3_EMA.plot(figsize=(25,10))

# %%
# Exponential 30 Day Moving Average Crypto 4
Crypto_4_EMA= df4['Close'].ewm(span=30, adjust=False).mean()
Crypto_4_EMA
# Out:
# Date
# 2017-06-03    0.003213
# 2017-06-04    0.003249
# 2017-06-05    0.003279
# 2017-06-06    0.003301
# 2017-06-07    0.003298
#                 ...
# 2021-06-21    0.324135
# 2021-06-22    0.315504
# 2021-06-23    0.310306
# 2021-06-24    0.307241
# 2021-06-25    0.302746
# Name: Close, Length: 1484, dtype: float64

# %%
Crypto_4_EMA.plot(figsize=(25,10))

# %%
# Exponential 30 Day Moving Average Crypto 5 
Crypto_5_EMA = df5['Close'].ewm(span=30, adjust=False).mean()
Crypto_5_EMA
# Out:
# Date
# 2017-04-14    0.989900
# 2017-04-15    0.989881
# 2017-04-16    0.987404
# 2017-04-17    0.984295
# 2017-04-18    0.981759
#                 ...
# 2021-06-21    1.000536
# 2021-06-22    1.000579
# 2021-06-23    1.000574
# 2021-06-24    1.000537
# 2021-06-25    1.000489
# Name: Close, Length: 1533, dtype: float64

# %%
Crypto_5_EMA.plot(figsize=(25,10))

# %%
# Crypto 1 Standard Deviation
Crypto_1_std= df1['Close'].std()
Crypto_1_std
# Out:
# 12283.083706132624

# %%
# Rolling Standard Deviation Crypto 1  
Crypto_1_roll_std= df1['Close'].rolling(window=30).std()
Crypto_1_roll_std
# Out:
# Date
# 2015-06-25            NaN
# 2015-06-26            NaN
# 2015-06-27            NaN
# 2015-06-28            NaN
# 2015-06-29            NaN
#                  ...
# 2021-06-21    2074.069740
# 2021-06-22    2184.766521
# 2021-06-23    2215.444705
# 2021-06-24    2211.367663
# 2021-06-25    2309.520039
# Name: Close, Length: 2193, dtype: float64

# %%
Crypto_1_roll_std.plot(figsize=(25,10))

# %%
# Standard Deviation Crypto 2 
Crypto_2_roll_std = df2['Close'].rolling(window=30).std()
Crypto_2_roll_std
# Out:
# Date
# 2016-03-10           NaN
# 2016-03-11           NaN
# 2016-03-12           NaN
# 2016-03-13           NaN
# 2016-03-14           NaN
#                  ...
# 2021-06-21    230.833100
# 2021-06-22    247.152128
# 2021-06-23    262.728932
# 2021-06-24    272.597483
# 2021-06-25    282.821416
# Name: Close, Length: 1934, dtype: float64

# %%
Crypto_2_roll_std.plot(figsize=(25,10))

# %%
# Standard Deviation Crypto 3 
Crypto_3_roll_std = df3['Close'].rolling(window=30).std()
Crypto_3_roll_std
# Out:
# Date
# 2017-12-31         NaN
# 2018-01-01         NaN
# 2018-01-02         NaN
# 2018-01-03         NaN
# 2018-01-04         NaN
#                 ...
# 2021-06-21    0.146993
# 2021-06-22    0.158806
# 2021-06-23    0.168068
# 2021-06-24    0.171401
# 2021-06-25    0.172488
# Name: Close, Length: 1273, dtype: float64

# %%
Crypto_3_roll_std.plot(figsize=(25,10))

# %%
# Standard Deviation Crypto 4 
Crypto_4_roll_std = df4['Close'].rolling(window=30).std()
Crypto_4_roll_std
# Out:
# Date
# 2017-06-03         NaN
# 2017-06-04         NaN
# 2017-06-05         NaN
# 2017-06-06         NaN
# 2017-06-07         NaN
#                 ...
# 2021-06-21    0.043957
# 2021-06-22    0.050420
# 2021-06-23    0.052236
# 2021-06-24    0.052935
# 2021-06-25    0.054368
# Name: Close, Length: 1484, dtype: float64

# %%
Crypto_4_roll_std.plot(figsize=(25,10))

# %%
# Standard Deviation Crypto 5 
Crypto_5_roll_std = df5['Close'].rolling(window=30).std()
Crypto_5_roll_std
# Out:
# Date
# 2017-04-14         NaN
# 2017-04-15         NaN
# 2017-04-16         NaN
# 2017-04-17         NaN
# 2017-04-18         NaN
#                 ...
# 2021-06-21    0.000567
# 2021-06-22    0.000535
# 2021-06-23    0.000527
# 2021-06-24    0.000515
# 2021-06-25    0.000487
# Name: Close, Length: 1533, dtype: float64

# %%
Crypto_5_roll_std.plot(figsize=(25,10))

# %%
# 30 Day Rolling Average Crypto 1
Crypto_1_sma = df1['Close'].rolling(window=30).mean()
Crypto_1_sma
# Out:
# Date
# 2015-06-25             NaN
# 2015-06-26             NaN
# 2015-06-27             NaN
# 2015-06-28             NaN
# 2015-06-29             NaN
#                   ...
# 2021-06-21    36755.420000
# 2021-06-22    36682.643333
# 2021-06-23    36513.433333
# 2021-06-24    36389.683333
# 2021-06-25    36134.510000
# Name: Close, Length: 2193, dtype: float64

# %%
Crypto_1_sma.plot(figsize=(30,10))

# %%
# 30 Day Rolling Average Crypto 2
Crypto_2_sma = df2['Close'].rolling(window=30).mean()
Crypto_2_sma
# Out:
# Date
# 2016-03-10            NaN
# 2016-03-11            NaN
# 2016-03-12            NaN
# 2016-03-13            NaN
# 2016-03-14            NaN
#                  ...
# 2021-06-21    2496.143667
# 2021-06-22    2488.654333
# 2021-06-23    2466.041000
# 2021-06-24    2442.176000
# 2021-06-25    2406.373000
# Name: Close, Length: 1934, dtype: float64

# %%
Crypto_2_sma.plot(figsize=(30,10))

# %%
# 30 Day Rolling Average Crypto 3 
Crypto_3_sma = df3['Close'].rolling(window=30).mean()
Crypto_3_sma
# Out:
# Date
# 2017-12-31         NaN
# 2018-01-01         NaN
# 2018-01-02         NaN
# 2018-01-03         NaN
# 2018-01-04         NaN
#                 ...
# 2021-06-21    1.557267
# 2021-06-22    1.551828
# 2021-06-23    1.541936
# 2021-06-24    1.535435
# 2021-06-25    1.517993
# Name: Close, Length: 1273, dtype: float64

# %%
Crypto_3_sma.plot(figsize=(30,10))

# %%
# 30 Day Rolling Average Crypto 4
Crypto_4_sma = df4['Close'].rolling(window=30).mean()
Crypto_4_sma
# Out:
# Date
# 2017-06-03         NaN
# 2017-06-04         NaN
# 2017-06-05         NaN
# 2017-06-06         NaN
# 2017-06-07         NaN
#                 ...
# 2021-06-21    0.326578
# 2021-06-22    0.322723
# 2021-06-23    0.318407
# 2021-06-24    0.315651
# 2021-06-25    0.311887
# Name: Close, Length: 1484, dtype: float64

# %%
Crypto_4_sma.plot(figsize=(30,10))

# %%
# 30 Day Rolling Average Crypto 5 
Crypto_5_sma = df5['Close'].rolling(window=30).mean()
Crypto_5_sma
# Out:
# Date
# 2017-04-14         NaN
# 2017-04-15         NaN
# 2017-04-16         NaN
# 2017-04-17         NaN
# 2017-04-18         NaN
#                 ...
# 2021-06-21    1.000437
# 2021-06-22    1.000420
# 2021-06-23    1.000407
# 2021-06-24    1.000370
# 2021-06-25    1.000317
# Name: Close, Length: 1533, dtype: float64

# %%
Crypto_5_sma.plot(figsize=(30,10))

# %%
# 60 Day Moving Average Crypto 1
Crypto_1_sma_60 = df1['Close'].rolling(window=60).mean()
Crypto_1_sma_60
# Out:
# Date
# 2015-06-25             NaN
# 2015-06-26             NaN
# 2015-06-27             NaN
# 2015-06-28             NaN
# 2015-06-29             NaN
#                   ...
# 2021-06-21    43914.218333
# 2021-06-22    43603.431667
# 2021-06-23    43329.855000
# 2021-06-24    43091.558333
# 2021-06-25    42717.783333
# Name: Close, Length: 2193, dtype: float64

# %%
Crypto_1_sma_60.plot(figsize=(30,10))

# %%
# 60  Day Moving Average Crypto 2 
Crypto_2_sma_60 = df2['Close'].rolling(window=60).mean()
Crypto_2_sma_60
# Out:
# Date
# 2016-03-10            NaN
# 2016-03-11            NaN
# 2016-03-12            NaN
# 2016-03-13            NaN
# 2016-03-14            NaN
#                  ...
# 2021-06-21    2828.880333
# 2021-06-22    2820.702833
# 2021-06-23    2816.577167
# 2021-06-24    2811.121500
# 2021-06-25    2799.079000
# Name: Close, Length: 1934, dtype: float64

# %%
Crypto_2_sma_60.plot(figsize=(30,10))

# %%
# 60 Day Moving Average Crypto 3
Crypto_3_sma_60 = df3['Close'].rolling(window=60).mean()
Crypto_3_sma_60
# Out:
# Date
# 2017-12-31         NaN
# 2018-01-01         NaN
# 2018-01-02         NaN
# 2018-01-03         NaN
# 2018-01-04         NaN
#                 ...
# 2021-06-21    1.563476
# 2021-06-22    1.563396
# 2021-06-23    1.565870
# 2021-06-24    1.570323
# 2021-06-25    1.570661
# Name: Close, Length: 1273, dtype: float64

# %%
Crypto_3_sma_60.plot(figsize=(30,10))

# %%
# 60 Day Moving Average Crypto 4 
Crypto_4_sma_60 = df4['Close'].rolling(window=60).mean()
Crypto_4_sma_60
# Out:
# Date
# 2017-06-03         NaN
# 2017-06-04         NaN
# 2017-06-05         NaN
# 2017-06-06         NaN
# 2017-06-07         NaN
#                 ...
# 2021-06-21    0.379083
# 2021-06-22    0.378109
# 2021-06-23    0.377525
# 2021-06-24    0.377720
# 2021-06-25    0.377182
# Name: Close, Length: 1484, dtype: float64

# %%
Crypto_4_sma_60.plot(figsize=(30,10))

# %%
# 60 Day Moving Average Crypto 5
Crypto_5_sma_60 = df5['Close'].rolling(window=60).mean()
Crypto_5_sma_60
# Out:
# Date
# 2017-04-14         NaN
# 2017-04-15         NaN
# 2017-04-16         NaN
# 2017-04-17         NaN
# 2017-04-18         NaN
#                 ...
# 2021-06-21    1.000677
# 2021-06-22    1.000683
# 2021-06-23    1.000662
# 2021-06-24    1.000642
# 2021-06-25    1.000623
# Name: Close, Length: 1533, dtype: float64

# %%
Crypto_5_sma_60.plot(figsize=(30,10))

# %%
# Crypto 1 Variance
Crypto_1_var= crypto_daily_returns['Bitcoin'].rolling(30).var()
Crypto_1_var
# Out:
# Date
# 2018-01-01         NaN
# 2018-01-02         NaN
# 2018-01-03         NaN
# 2018-01-04         NaN
# 2018-01-05         NaN
#                 ...
# 2021-06-21    0.003003
# 2021-06-22    0.002854
# 2021-06-23    0.002412
# 2021-06-24    0.002446
# 2021-06-25    0.002668
# Name: Bitcoin, Length: 1271, dtype: float64

# %%
Crypto_1_var.plot(figsize=(30,10))

# %%
# Crypto 2 Variance
Crypto_2_var= crypto_daily_returns['Ethereum'].rolling(30).var()
Crypto_2_var
# Out:
# Date
# 2018-01-01         NaN
# 2018-01-02         NaN
# 2018-01-03         NaN
# 2018-01-04         NaN
# 2018-01-05         NaN
#                 ...
# 2021-06-21    0.006130
# 2021-06-22    0.005906
# 2021-06-23    0.003599
# 2021-06-24    0.003580
# 2021-06-25    0.003587
# Name: Ethereum, Length: 1271, dtype: float64

# %%
Crypto_2_var.plot(figsize=(30,10))

# %%
# Crypto 3 Variance
Crypto_3_var= crypto_daily_returns['Cardano'].rolling(30).var()
Crypto_3_var
# Out:
# Date
# 2018-01-01         NaN
# 2018-01-02         NaN
# 2018-01-03         NaN
# 2018-01-04         NaN
# 2018-01-05         NaN
#                 ...
# 2021-06-21    0.005797
# 2021-06-22    0.005476
# 2021-06-23    0.004634
# 2021-06-24    0.004903
# 2021-06-25    0.004280
# Name: Cardano, Length: 1271, dtype: float64

# %%
Crypto_3_var.plot(figsize=(30,10))

# %%
# Crypto 4 Variance
Crypto_4_var= crypto_daily_returns['Dogecoin'].rolling(30).var()
Crypto_4_var
# Out:
# Date
# 2018-01-01         NaN
# 2018-01-02         NaN
# 2018-01-03         NaN
# 2018-01-04         NaN
# 2018-01-05         NaN
#                 ...
# 2021-06-21    0.008809
# 2021-06-22    0.008722
# 2021-06-23    0.009386
# 2021-06-24    0.009856
# 2021-06-25    0.010124
# Name: Dogecoin, Length: 1271, dtype: float64

# %%
Crypto_4_var.plot(figsize=(30,10))

# %%
# Crypto 5 Variance
Crypto_5_var= crypto_daily_returns['Tether'].rolling(30).var()
Crypto_5_var
# Out:
# Date
# 2018-01-01             NaN
# 2018-01-02             NaN
# 2018-01-03             NaN
# 2018-01-04             NaN
# 2018-01-05             NaN
#                   ...
# 2021-06-21    1.816194e-07
# 2021-06-22    1.846141e-07
# 2021-06-23    1.795782e-07
# 2021-06-24    1.856123e-07
# 2021-06-25    1.823483e-07
# Name: Tether, Length: 1271, dtype: float64

# %%
Crypto_5_var.plot(figsize=(30,10))

# %%
# Calculate cumulative returns of aall cryptocurrencies
cumulative_returns = (1 + crypto_daily_returns).cumprod()
cumulative_returns.plot(figsize=(30, 30), title="Cumulative Returns")

# %%
cumulative_returns.head()
# Out:
#              Bitcoin  Ethereum   Cardano  Dogecoin    Tether
# Date
# 2018-01-01  0.970723  1.021296  0.989014  0.972107  0.990196
# 2018-01-02  1.065247  1.165601  1.073239  1.008177  1.000000
# 2018-01-03  1.094308  1.278567  1.521127  1.031141  0.990196
# 2018-01-04  1.096004  1.275839  1.555352  1.076846  1.000000
# 2018-01-05  1.224138  1.306744  1.401272  1.405847  0.980392

# %%
# Correlation of Daily Return for different Cryptocurrencies
corr_df = crypto_daily_returns.corr()
corr_df.style.background_gradient(cmap="bwr")
# Out:
# <style  type="text/css" >
#     #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row0_col0 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row0_col1 {
#             background-color:  #ff6464;
#             color:  #000000;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row0_col2 {
#             background-color:  #ffa6a6;
#             color:  #000000;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row0_col3 {
#             background-color:  #0404ff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row0_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row1_col0 {
#             background-color:  #ff6262;
#             color:  #000000;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row1_col1 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row1_col2 {
#             background-color:  #ff7a7a;
#             color:  #000000;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row1_col3 {
#             background-color:  #0202ff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row1_col4 {
#             background-color:  #0a0aff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row2_col0 {
#             background-color:  #ff9e9e;
#             color:  #000000;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row2_col1 {
#             background-color:  #ff7878;
#             color:  #000000;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row2_col2 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row2_col3 {
#             background-color:  #0808ff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row2_col4 {
#             background-color:  #1212ff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row3_col0 {
#             background-color:  #1010ff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row3_col1 {
#             background-color:  #0404ff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row3_col2 {
#             background-color:  #0202ff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row3_col3 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row3_col4 {
#             background-color:  #0c0cff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row4_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row4_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row4_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row4_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row4_col4 {
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }</style><table id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Bitcoin</th>        <th class="col_heading level0 col1" >Ethereum</th>        <th class="col_heading level0 col2" >Cardano</th>        <th class="col_heading level0 col3" >Dogecoin</th>        <th class="col_heading level0 col4" >Tether</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8level0_row0" class="row_heading level0 row0" >Bitcoin</th>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row0_col1" class="data row0 col1" >0.806224</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row0_col2" class="data row0 col2" >0.684238</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row0_col3" class="data row0 col3" >0.021992</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row0_col4" class="data row0 col4" >-0.011910</td>
#             </tr>
#             <tr>
#                         <th id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8level0_row1" class="row_heading level0 row1" >Ethereum</th>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row1_col0" class="data row1 col0" >0.806224</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row1_col2" class="data row1 col2" >0.764337</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row1_col3" class="data row1 col3" >0.021230</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row1_col4" class="data row1 col4" >0.010873</td>
#             </tr>
#             <tr>
#                         <th id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8level0_row2" class="row_heading level0 row2" >Cardano</th>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row2_col0" class="data row2 col0" >0.684238</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row2_col1" class="data row2 col1" >0.764337</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row2_col3" class="data row2 col3" >0.031590</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row2_col4" class="data row2 col4" >0.026864</td>
#             </tr>
#             <tr>
#                         <th id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8level0_row3" class="row_heading level0 row3" >Dogecoin</th>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row3_col0" class="data row3 col0" >0.021992</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row3_col1" class="data row3 col1" >0.021230</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row3_col2" class="data row3 col2" >0.031590</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row3_col4" class="data row3 col4" >0.014152</td>
#             </tr>
#             <tr>
#                         <th id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8level0_row4" class="row_heading level0 row4" >Tether</th>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row4_col0" class="data row4 col0" >-0.011910</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row4_col1" class="data row4 col1" >0.010873</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row4_col2" class="data row4 col2" >0.026864</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row4_col3" class="data row4 col3" >0.014152</td>
#                         <td id="T_ead84414_dc28_11eb_9e09_f06e0bcf50a8row4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (crypto_daily_returns.mean() * 252) / (crypto_daily_returns.std() * np.sqrt(252))
sharpe_ratios
# Out:
# Bitcoin     0.584571
# Ethereum    0.646017
# Cardano     0.619774
# Dogecoin    0.502997
# Tether     -0.054550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")

# %%
#Data Visualizations(AHMED)
'''
PLEASE CREATE ATLEAST 6-8 VISUALIZATIONS AND A DASHBOARD CONTAINING THESE VISUALIZATIONS
1)Use Pyviz
2)Plotly express
3)Panel 
4)Hvplot
5)Dashboard'''
# Out:
# '\nPLEASE CREATE ATLEAST 6-8 VISUALIZATIONS AND A DASHBOARD CONTAINING THESE VISUALIZATIONS\n1)Use Pyviz\n2)Plotly express\n3)Panel \n4)Hvplot\n5)Dashboard'

# %%
#MC SIMULATIONS (GIORGIO)
# 1)Configuring a Monte Carlo simulation to forecast 10 years cumulative returns
# Running a Monte Carlo simulation to forecast 15 years cumulative returns
# Plot simulation outcomes
# Plot probability distribution and confidence intervals
# Fetch summary statistics from the Monte Carlo simulation results and print the summary stats
# Set initial investment and Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes for the investment

# 2)Configuring a Monte Carlo simulation to forecast 5 years cumulative returns
# Running a Monte Carlo simulation to forecast 5 years cumulative returns
# Plot simulation outcomes
# Plot probability distribution and confidence intervals
# Fetch summary statistics from the Monte Carlo simulation results and print the summary stats
# Set initial investment and Use the lower and upper `95%` confidence intervals to calculate the range of the possible outcomes for the investment
